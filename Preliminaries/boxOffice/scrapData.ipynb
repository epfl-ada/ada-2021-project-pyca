# %%
import pandas as pd

# %% [markdown]
# # Notebook to create a meaningful movie data set
# For now data comes from 2 sources
# - the imdb data sets to download [link](https://datasets.imdbws.com/) (not stored on github, to run the notebook -> download relevant data). Contains many info ratings etc but not box-office and in a not convenient way (SQL storage)
# - boxoffice stats, for now from [link](https://www.boxofficemojo.com/year/2015/)
#
# **Goal**: for each 2015-2020 US movie get ratings, boxoffice, director names...

# %% [markdown]
# ## Preprocessing of some imdb data sets
# ### Keep relevant years

# %%
df1 = pd.read_csv('./data/title.basics.tsv.gz', compression='gzip', header=0, sep='\t', na_values='\\N')
# Out:
# /Users/goujon/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# keep only movies and start year >= 2015
df1 = df1[(df1['startYear']>=2015)&(df1['titleType']=="movie")]
df1.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 11059  tt0011216     movie                                     Spanish Fiesta
# 11636  tt0011801     movie                                   Tötet nicht mehr
# 61124  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 64098  tt0065392     movie                                 Bucharest Memories
# 67677  tt0069049     movie                         The Other Side of the Wind
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 11059                          La fête espagnole      0.0     2019.0      NaN
# 11636                           Tötet nicht mehr      0.0     2019.0      NaN
# 61124  El Tango del Viudo y Su Espejo Deformante      0.0     2020.0      NaN
# 64098                       Amintiri bucurestene      0.0     2020.0      NaN
# 67677                 The Other Side of the Wind      0.0     2018.0      NaN
#
#       runtimeMinutes        genres
# 11059           67.0         Drama
# 11636            NaN  Action,Crime
# 61124           70.0         Drama
# 64098            NaN   Documentary
# 67677          122.0         Drama

# %%
# get titles
df = pd.read_csv('./data/title.akas.tsv.gz', compression='gzip', header=0, sep='\t', na_values='\\N')
df.head()
# Out:
# /Users/goujon/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes  isOriginalTitle
# 0  imdbDisplay            NaN              0.0
# 1          NaN  literal title              0.0
# 2  imdbDisplay            NaN              0.0
# 3  imdbDisplay            NaN              0.0
# 4  imdbDisplay            NaN              0.0

# %%
# Select only US
df2 = df[df["region"]=="US"]

# %%
# Merge
df_data = pd.merge(df1,df2,how="inner",left_on="tconst",right_on="titleId")
df_data.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 1  tt0065392     movie                                 Bucharest Memories
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0100275     movie                           The Wandering Soap Opera
# 4  tt0112502     movie                                            Bigfoot
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0  El Tango del Viudo y Su Espejo Deformante      0.0     2020.0      NaN
# 1                       Amintiri bucurestene      0.0     2020.0      NaN
# 2                 The Other Side of the Wind      0.0     2018.0      NaN
# 3                      La telenovela errante      0.0     2017.0      NaN
# 4                                    Bigfoot      0.0     2017.0      NaN
#
#   runtimeMinutes                genres    titleId  ordering  \
# 0           70.0                 Drama  tt0062336         5
# 1            NaN           Documentary  tt0065392         3
# 2          122.0                 Drama  tt0069049         3
# 3           80.0  Comedy,Drama,Fantasy  tt0100275         6
# 4            NaN       Horror,Thriller  tt0112502         3
#
#                                                title region language  \
# 0  The Tango of the Widower and Its Distorting Mi...     US      NaN
# 1                                 Bucharest Memories     US      NaN
# 2                         The Other Side of the Wind     US      NaN
# 3                           The Wandering Soap Opera     US      NaN
# 4                                            Bigfoot     US      NaN
#
#          types attributes  isOriginalTitle
# 0  imdbDisplay        NaN              0.0
# 1  imdbDisplay        NaN              0.0
# 2  imdbDisplay        NaN              0.0
# 3  imdbDisplay        NaN              0.0
# 4  imdbDisplay        NaN              0.0

# %% [markdown]
# ## Box-office data from the web

# %%
# scrap boxoffice
df_box = pd.read_html("https://www.boxofficemojo.com/year/2015/")[0]
df.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes  isOriginalTitle
# 0  imdbDisplay            NaN              0.0
# 1          NaN  literal title              0.0
# 2  imdbDisplay            NaN              0.0
# 3  imdbDisplay            NaN              0.0
# 4  imdbDisplay            NaN              0.0

# %%
# merge boxoffice data
df4 = pd.merge(df_data,df_box,how="inner",left_on="primaryTitle",right_on="Release")
# remove duplicates: only keep first for now
df4 = df4.groupby("Release").agg(lambda x: x.iloc[0])
df4.head()
# Out:
#                                            tconst titleType  \
# Release
# 90 Minutes in Heaven                    tt4337690     movie
# A Walk in the Woods                     tt1178665     movie
# A la mala                               tt4357170     movie
# Aloha                                   tt1243974     movie
# Alvin and the Chipmunks: The Road Chip  tt2974918     movie
#
#                                                                   primaryTitle  \
# Release
# 90 Minutes in Heaven                                      90 Minutes in Heaven
# A Walk in the Woods                                        A Walk in the Woods
# A la mala                                                            A la mala
# Aloha                                                                    Aloha
# Alvin and the Chipmunks: The Road Chip  Alvin and the Chipmunks: The Road Chip
#
#                                                                  originalTitle  \
# Release
# 90 Minutes in Heaven                                      90 Minutes in Heaven
# A Walk in the Woods                                        A Walk in the Woods
# A la mala                                                            A la mala
# Aloha                                                                    Aloha
# Alvin and the Chipmunks: The Road Chip  Alvin and the Chipmunks: The Road Chip
#
#                                         isAdult  startYear  endYear  \
# Release
# 90 Minutes in Heaven                        0.0     2015.0      NaN
# A Walk in the Woods                         0.0     2015.0      NaN
# A la mala                                   0.0     2015.0      NaN
# Aloha                                       0.0     2015.0      NaN
# Alvin and the Chipmunks: The Road Chip      0.0     2015.0      NaN
#
#                                        runtimeMinutes  \
# Release
# 90 Minutes in Heaven                            121.0
# A Walk in the Woods                               104
# A la mala                                        99.0
# Aloha                                             105
# Alvin and the Chipmunks: The Road Chip           92.0
#
#                                                             genres    titleId  \
# Release
# 90 Minutes in Heaven                                         Drama  tt4337690
# A Walk in the Woods                     Adventure,Biography,Comedy  tt1178665
# A la mala                                                   Comedy  tt4357170
# Aloha                                         Comedy,Drama,Romance  tt1243974
# Alvin and the Chipmunks: The Road Chip  Adventure,Animation,Comedy  tt2974918
#
#                                         ...  Rank Genre Budget  Running Time  \
# Release                                 ...
# 90 Minutes in Heaven                    ...   165     -      -             -
# A Walk in the Woods                     ...    84     -      -             -
# A la mala                               ...   178     -      -             -
# Aloha                                   ...   104     -      -             -
# Alvin and the Chipmunks: The Road Chip  ...    53     -      -             -
#
#                                               Gross Theaters  Total Gross  \
# Release
# 90 Minutes in Heaven                     $4,842,699      899   $4,842,699
# A Walk in the Woods                     $29,474,282     2158  $29,504,281
# A la mala                                $3,629,842      384   $3,629,842
# Aloha                                   $21,067,116     2815  $21,067,116
# Alvin and the Chipmunks: The Road Chip  $55,575,427     3705  $85,886,987
#
#                                         Release Date  \
# Release
# 90 Minutes in Heaven                          Sep 11
# A Walk in the Woods                            Sep 2
# A la mala                                     Feb 27
# Aloha                                         May 29
# Alvin and the Chipmunks: The Road Chip        Dec 18
#
#                                                               Distributor  \
# Release
# 90 Minutes in Heaven                           The Samuel Goldwyn Company
# A Walk in the Woods                                  Broad Green Pictures
# A la mala                                                       Lionsgate
# Aloha                                   Sony Pictures Entertainment (SPE)
# Alvin and the Chipmunks: The Road Chip              Twentieth Century Fox
#
#                                        Estimated
# Release
# 90 Minutes in Heaven                       False
# A Walk in the Woods                        False
# A la mala                                  False
# Aloha                                      False
# Alvin and the Chipmunks: The Road Chip     False
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Back to IMDB to find director names

# %% [markdown]
# ### Find film directors with ids

# %%
df_crew = pd.read_csv('./data/title.crew.tsv.gz', compression='gzip', header=0, sep='\t', na_values='\\N')
df_crew.head()
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690     NaN
# 1  tt0000002  nm0721526     NaN
# 2  tt0000003  nm0721526     NaN
# 3  tt0000004  nm0721526     NaN
# 4  tt0000005  nm0005690     NaN

# %%
df5 = pd.merge(df4,df_crew,how="left",left_on="tconst",right_on="tconst")
# director field to array
df5["directors"] = df5["directors"].apply(lambda x:x.split(","))
# explode directors
df5 = df5.explode('directors')
df5.head()
# Out:
#       tconst titleType                            primaryTitle  \
# 0  tt4337690     movie                    90 Minutes in Heaven
# 1  tt1178665     movie                     A Walk in the Woods
# 2  tt4357170     movie                               A la mala
# 3  tt1243974     movie                                   Aloha
# 4  tt2974918     movie  Alvin and the Chipmunks: The Road Chip
#
#                             originalTitle  isAdult  startYear  endYear  \
# 0                    90 Minutes in Heaven      0.0     2015.0      NaN
# 1                     A Walk in the Woods      0.0     2015.0      NaN
# 2                               A la mala      0.0     2015.0      NaN
# 3                                   Aloha      0.0     2015.0      NaN
# 4  Alvin and the Chipmunks: The Road Chip      0.0     2015.0      NaN
#
#   runtimeMinutes                      genres    titleId  ...  Budget  \
# 0          121.0                       Drama  tt4337690  ...       -
# 1            104  Adventure,Biography,Comedy  tt1178665  ...       -
# 2           99.0                      Comedy  tt4357170  ...       -
# 3            105        Comedy,Drama,Romance  tt1243974  ...       -
# 4           92.0  Adventure,Animation,Comedy  tt2974918  ...       -
#
#   Running Time        Gross  Theaters  Total Gross Release Date  \
# 0            -   $4,842,699       899   $4,842,699       Sep 11
# 1            -  $29,474,282      2158  $29,504,281        Sep 2
# 2            -   $3,629,842       384   $3,629,842       Feb 27
# 3            -  $21,067,116      2815  $21,067,116       May 29
# 4            -  $55,575,427      3705  $85,886,987       Dec 18
#
#                          Distributor  Estimated  directors  \
# 0         The Samuel Goldwyn Company      False  nm0689187
# 1               Broad Green Pictures      False  nm0477129
# 2                          Lionsgate      False  nm0950426
# 3  Sony Pictures Entertainment (SPE)      False  nm0001081
# 4              Twentieth Century Fox      False  nm0065608
#
#                                    writers
# 0            nm0689187,nm2926858,nm7714780
# 1            nm1578335,nm2250139,nm0117445
# 2                      nm0411517,nm7053880
# 3                                nm0001081
# 4  nm0046564,nm0439739,nm0802020,nm1186373
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Film directors: from id to names

# %%
df_name = pd.read_csv('./data/name.basics.tsv.gz', compression='gzip', header=0, sep='\t', na_values='\\N')

# %%
df6 = pd.merge(df5,df_name,how="inner",left_on="directors",right_on="nconst")
df6.head()
# Out:
#       tconst titleType                            primaryTitle  \
# 0  tt4337690     movie                    90 Minutes in Heaven
# 1  tt1178665     movie                     A Walk in the Woods
# 2  tt4357170     movie                               A la mala
# 3  tt1243974     movie                                   Aloha
# 4  tt2974918     movie  Alvin and the Chipmunks: The Road Chip
#
#                             originalTitle  isAdult  startYear  endYear  \
# 0                    90 Minutes in Heaven      0.0     2015.0      NaN
# 1                     A Walk in the Woods      0.0     2015.0      NaN
# 2                               A la mala      0.0     2015.0      NaN
# 3                                   Aloha      0.0     2015.0      NaN
# 4  Alvin and the Chipmunks: The Road Chip      0.0     2015.0      NaN
#
#   runtimeMinutes                      genres    titleId  ...  \
# 0          121.0                       Drama  tt4337690  ...
# 1            104  Adventure,Biography,Comedy  tt1178665  ...
# 2           99.0                      Comedy  tt4357170  ...
# 3            105        Comedy,Drama,Romance  tt1243974  ...
# 4           92.0  Adventure,Animation,Comedy  tt2974918  ...
#
#                          Distributor Estimated  directors  \
# 0         The Samuel Goldwyn Company     False  nm0689187
# 1               Broad Green Pictures     False  nm0477129
# 2                          Lionsgate     False  nm0950426
# 3  Sony Pictures Entertainment (SPE)     False  nm0001081
# 4              Twentieth Century Fox     False  nm0065608
#
#                                    writers     nconst     primaryName  \
# 0            nm0689187,nm2926858,nm7714780  nm0689187  Michael Polish
# 1            nm1578335,nm2250139,nm0117445  nm0477129      Ken Kwapis
# 2                      nm0411517,nm7053880  nm0950426  Pitipol Ybarra
# 3                                nm0001081  nm0001081   Cameron Crowe
# 4  nm0046564,nm0439739,nm0802020,nm1186373  nm0065608     Walt Becker
#
#    birthYear  deathYear                    primaryProfession  \
# 0     1970.0        NaN             director,producer,writer
# 1     1957.0        NaN             director,producer,writer
# 2        NaN        NaN  director,producer,camera_department
# 3     1957.0        NaN             writer,producer,director
# 4     1968.0        NaN             director,producer,writer
#
#                             knownForTitles
# 0  tt0162830,tt0261755,tt0322659,tt1462411
# 1  tt3095080,tt1178665,tt4947608,tt1430615
# 2  tt6156346,tt1068899,tt9893062,tt4357170
# 3  tt0116695,tt0105415,tt0181875,tt0259711
# 4  tt0283111,tt0976238,tt0486946,tt1684734
#
# [5 rows x 35 columns]

# %%
df6.to_csv("movie_data_2015.csv")
