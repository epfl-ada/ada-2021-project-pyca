# %% [markdown]
# # Create a meaningful movie data set
# We chose not to upload the datasets we use on github because they were too big ; this notebook downloads and merges them.
#
# The two data sources are:
# - the **IMDb datasets** [link](https://datasets.imdbws.com/) that have to be downloaded and put in a `data` folder. They contains many information (ratings, etc), but not the box-office, and not in a convenient format (each SQL table is in its own tsv file).
# - the **Box Office Mojo stats** [link](https://www.boxofficemojo.com/year/), that are crawled and merged with the IMDb datasets in this notebook.
#
# The initial architecture to run this notebook should be the following:
# ```
#     .
#     └── moviePreprocessing
#         ├── movieDataSetBuilder.ipynb    # this notebook
#         └── data/                        # the datasets we need
#             ├── name.basics.tsv.gz
#             ├── title.akas.tsv.gz
#             ├── title.basics.tsv.gz
#             ├── title.crew.tsv.gz
#             ├── title.episode.tsv.gz
#             ├── title.principals.tsv.gz
#             └── title.ratings.tsv.gz
# ```
# where each files comes from the IMDb datasets, whose specification can be found at https://www.imdb.com/interfaces/.
#
# **The goal of this notebook is to generate a dataset containing the ratings, boxoffice, director names and main actor names, for each US and UK movie, from 2015 to 2020. This dataset will be named `movie_data_2015_2020.csv` and located in the `moviePreprocessing` folder.**

# %%
# Initial imports
import pandas as pd
import csv

# Constants to easily update and read the code
DATA_DIR = "./data/"
OUT_DATASET = "./movie_data_2015_2020.csv"

# Auxiliary functions

# Reads the csv with the given name.
def read_csv(name, dtype={}):
    return pd.read_csv(DATA_DIR + name,
                       compression='gzip',
                       header=0,
                       sep='\t',
                       na_values='\\N',
                       dtype=dtype,
                       quoting=csv.QUOTE_NONE)

# If st is a string, applies the conv translation, otherwise returns st unchanged 
def strtranslate(st, conv):
    if type(st) == str:
        return st.translate(conv)
    return st

# %% [markdown]
# ## Processing the IMDb data sets
# The dataset is organized in an "SQL way", each table being in its own compressed tsv file.
#
# We are going to filter the data and merge the datasets to get all the info needed about a movie in one csv file.
#
# ### Filter relevant years only

# %%
# Read the `title.basics.tsv.gz` table, which contains unique information about the movies:
# type, titles, start and end years, genres, duration, adult rating
# (the datasets contains information about more than only movies, hence a `type` column)
titlesbasic = read_csv('title.basics.tsv.gz')

# %%
# Example to see what the table looks like:

# Extract the movies whose name contains `Star Wars: Episode V`,
# display only the first 10 results
titlesbasic[titlesbasic["primaryTitle"].str.contains("Star Wars: Episode V", na=False)].head(10)
# Out:
#              tconst  titleType  \
# 78976     tt0080684      movie
# 84322     tt0086190      movie
# 1318718  tt10618318  tvEpisode
# 1326452  tt10631820  tvEpisode
# 1486127  tt10910686  tvEpisode
# 1515781  tt10962828  tvEpisode
# 1535258  tt10996576  tvEpisode
# 1603009  tt11114174  tvEpisode
# 1685170  tt11261064  tvEpisode
# 1685177  tt11261078  tvEpisode
#
#                                               primaryTitle  \
# 78976       Star Wars: Episode V - The Empire Strikes Back
# 84322           Star Wars: Episode VI - Return of the Jedi
# 1318718     Star Wars: Episode V - The Empire Strikes Back
# 1326452         Star Wars: Episode VI - Return of the Jedi
# 1486127     Star Wars: Episode V - The Empire Strikes Back
# 1515781  Everything GREAT About Star Wars: Episode VII ...
# 1535258         Star Wars: Episode VI - Return of the Jedi
# 1603009  RICK REACTS ~ Star Wars: Episode VII - The For...
# 1685170  Everything GREAT About Star Wars: Episode V - ...
# 1685177  Everything GREAT About Star Wars: Episode VI -...
#
#                                              originalTitle  isAdult  \
# 78976       Star Wars: Episode V - The Empire Strikes Back        0
# 84322           Star Wars: Episode VI - Return of the Jedi        0
# 1318718     Star Wars: Episode V - The Empire Strikes Back        0
# 1326452         Star Wars: Episode VI - Return of the Jedi        0
# 1486127     Star Wars: Episode V - The Empire Strikes Back        0
# 1515781  Everything GREAT About Star Wars: Episode VII ...        0
# 1535258         Star Wars: Episode VI - Return of the Jedi        0
# 1603009  RICK REACTS ~ Star Wars: Episode VII - The For...        0
# 1685170  Everything GREAT About Star Wars: Episode V - ...        0
# 1685177  Everything GREAT About Star Wars: Episode VI -...        0
#
#          startYear  endYear  runtimeMinutes                    genres
# 78976       1980.0      NaN           124.0  Action,Adventure,Fantasy
# 84322       1983.0      NaN           131.0  Action,Adventure,Fantasy
# 1318718     2019.0      NaN             NaN                    Comedy
# 1326452     2019.0      NaN             NaN                    Comedy
# 1486127     2019.0      NaN           127.0                 Talk-Show
# 1515781     2016.0      NaN            15.0                    Comedy
# 1535258     2019.0      NaN           133.0                 Talk-Show
# 1603009     2019.0      NaN            70.0                Reality-TV
# 1685170     2017.0      NaN            22.0                    Comedy
# 1685177     2017.0      NaN            24.0                    Comedy

# %%
# Keep only actual movies
titlesbasic = titlesbasic[titlesbasic['titleType'] == "movie"]

# Keep a one year margin for the start year, so in [2014;2021]
titlesbasic = titlesbasic[(titlesbasic['startYear'] >= 2014) & (titlesbasic['startYear'] <= 2021)]

print(titlesbasic.shape)
titlesbasic.head()
# Out:
# (134000, 9)
#           tconst titleType                                       primaryTitle  \
# 11059  tt0011216     movie                                     Spanish Fiesta
# 11636  tt0011801     movie                                   Tötet nicht mehr
# 16657  tt0016906     movie                                         Frivolinas
# 61124  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 64098  tt0065392     movie                                 Bucharest Memories
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 11059                          La fête espagnole        0     2019.0      NaN
# 11636                           Tötet nicht mehr        0     2019.0      NaN
# 16657                                 Frivolinas        0     2014.0      NaN
# 61124  El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 64098                       Amintiri bucurestene        0     2020.0      NaN
#
#        runtimeMinutes          genres
# 11059            67.0           Drama
# 11636             NaN    Action,Crime
# 16657            80.0  Comedy,Musical
# 61124            70.0           Drama
# 64098             NaN     Documentary

# %%
# Re-check our former example:
titlesbasic[titlesbasic["primaryTitle"].str.contains("Star Wars: Episode V", na=False)]
# Out:
#             tconst titleType                                primaryTitle  \
# 5019126  tt2488496     movie  Star Wars: Episode VII - The Force Awakens
# 5034390  tt2527336     movie     Star Wars: Episode VIII - The Last Jedi
#
#                                       originalTitle  isAdult  startYear  \
# 5019126  Star Wars: Episode VII - The Force Awakens        0     2015.0
# 5034390     Star Wars: Episode VIII - The Last Jedi        0     2017.0
#
#          endYear  runtimeMinutes                    genres
# 5019126      NaN           138.0   Action,Adventure,Sci-Fi
# 5034390      NaN           152.0  Action,Adventure,Fantasy

# %% [markdown]
# We can notice that all tv episodes are gone, and even the actual `Star Wars: Episode V` movie is gone since it's too old !
#
# The only remaining rows are `Star Wars: Episode VII` and `Star Wars: Episode VIII`.

# %%
# Read the `title.akas.tsv.gz` table, which contains information about the movies depending on the region:
# (the same movie can have various titles depending on the region for example)
# title, region, language, types, some more information about the title
titlesakas = read_csv('title.akas.tsv.gz', dtype={'attributes': str})
# (specify dtype to avoid a warning being displayed
# and map an unreadable character to a comma)
titlesakas.attributes = titlesakas.attributes.apply(lambda attr: strtranslate(attr, {'\x02':','}))

print(titlesakas.shape)
titlesakas.head()
# Out:
# (29700882, 8)
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes  isOriginalTitle
# 0  imdbDisplay            NaN              0.0
# 1          NaN  literal title              0.0
# 2  imdbDisplay            NaN              0.0
# 3  imdbDisplay            NaN              0.0
# 4  imdbDisplay            NaN              0.0

# %%
# Keep only the movies in the US and UK
titlesakas = titlesakas[(titlesakas["region"] == "US") | (titlesakas["region"] == "UK")]

# %%
# Merge both the `basic` movie dataset and the `alternative` movie dataset
# into a unique `moviedata` dataset, to which we will gradually add more information
moviedata = pd.merge(titlesbasic, titlesakas, how="inner", left_on="tconst", right_on="titleId")

print(moviedata.shape)
moviedata.head()
# Out:
# (71447, 17)
#       tconst titleType                                       primaryTitle  \
# 0  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 1  tt0065392     movie                                 Bucharest Memories
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0100275     movie                           The Wandering Soap Opera
# 4  tt0112502     movie                                            Bigfoot
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0  El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 1                       Amintiri bucurestene        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                      La telenovela errante        0     2017.0      NaN
# 4                                    Bigfoot        0     2017.0      NaN
#
#    runtimeMinutes                genres    titleId  ordering  \
# 0            70.0                 Drama  tt0062336         5
# 1             NaN           Documentary  tt0065392         3
# 2           122.0                 Drama  tt0069049         3
# 3            80.0  Comedy,Drama,Fantasy  tt0100275         6
# 4             NaN       Horror,Thriller  tt0112502         3
#
#                                                title region language  \
# 0  The Tango of the Widower and Its Distorting Mi...     US      NaN
# 1                                 Bucharest Memories     US      NaN
# 2                         The Other Side of the Wind     US      NaN
# 3                           The Wandering Soap Opera     US      NaN
# 4                                            Bigfoot     US      NaN
#
#          types attributes  isOriginalTitle
# 0  imdbDisplay        NaN              0.0
# 1  imdbDisplay        NaN              0.0
# 2  imdbDisplay        NaN              0.0
# 3  imdbDisplay        NaN              0.0
# 4  imdbDisplay        NaN              0.0

# %% [markdown]
# ## Box-office data from the web

# %%
# Scrap boxoffice for all years, and get an unique dataframe

# Scrap boxoffice for the given year
def scrap_boxoffice(year):
    df_box = pd.read_html(f"https://www.boxofficemojo.com/year/{year}/")[0]
    df_box["Year"] = year
    return df_box

# Concatenate each year's boxoffice
boxoffice = pd.concat([scrap_boxoffice(year) for year in range(2015, 2021)])
print(boxoffice.shape)
boxoffice.head()
# Out:
# (1200, 12)
#    Rank                                     Release Genre Budget Running Time  \
# 0     1                              Jurassic World     -      -            -
# 1     2  Star Wars: Episode VII - The Force Awakens     -      -            -
# 2     3                     Avengers: Age of Ultron     -      -            -
# 3     4                                  Inside Out     -      -            -
# 4     5                                   Furious 7     -      -            -
#
#           Gross Theaters   Total Gross Release Date  \
# 0  $652,270,625     4291  $652,270,625       Jun 12
# 1  $651,967,269     4134  $936,662,225       Dec 18
# 2  $459,005,868     4276  $459,005,868        May 1
# 3  $356,461,711     4158  $356,461,711       Jun 19
# 4  $353,007,020     4022  $353,007,020        Apr 3
#
#                            Distributor  Estimated  Year
# 0                   Universal Pictures      False  2015
# 1  Walt Disney Studios Motion Pictures      False  2015
# 2  Walt Disney Studios Motion Pictures      False  2015
# 3  Walt Disney Studios Motion Pictures      False  2015
# 4                   Universal Pictures      False  2015

# %%
# Unmatched movies
boxoffice[~boxoffice["Release"].isin(moviedata["primaryTitle"])]
# Out:
#      Rank                                            Release Genre Budget  \
# 150   151                                  The Green Inferno     -      -
# 170   171                                          Hubble 3D     -      -
# 198   199  The Oscar Nominated Short Films 2015: Live Action     -      -
# 153   154                         The Lobster2016 Re-release     -      -
# 173   174                         The Meddler2016 Re-release     -      -
# 180   181                                             Kabali     -      -
# 100   101                               Leap!2017 Re-release     -      -
# 185   186  Close Encounters of the Third Kind2017 Re-release     -      -
# 189   190  The Oscar Nominated Short Films 2017: Live Action     -      -
# 195   196  Showtime Championship Boxing: Floyd Mayweather...     -      -
# 166   167                Once Upon a Deadpool2018 Re-release     -      -
# 168   169                                             Pandas     -      -
# 196   197               2001: A Space Odyssey2018 Re-release     -      -
# 51     52                            The Curse of La Llorona     -      -
# 164   165                            Cold War2018 Re-release     -      -
# 165   166                                            Menteur     -      -
# 176   177  The Oscar Nominated Short Films 2019: Documentary     -      -
# 194   195                              Arctic2019 Re-release     -      -
# 52     53                         Hocus Pocus2020 Re-release     -      -
# 60     61                   2020 Oscar Nominated Short Films     -      -
# 66     67  Star Wars: Episode V - The Empire Strikes Back...     -      -
# 68     69      The Nightmare Before Christmas2020 Re-release     -      -
# 71     72                                 Elf2020 Re-release     -      -
# 78     79                       Jurassic Park2020 Re-release     -      -
# 92     93  National Lampoon's Christmas Vacation2020 Re-r...     -      -
# 96     97                         The Goonies2020 Re-release     -      -
# 100   101                                Jaws2020 Re-release     -      -
# 104   105                           Toy Story2020 Re-release     -      -
# 105   106                      Monsters, Inc.2020 Re-release     -      -
# 107   108                    The Santa Clause2020 Re-release     -      -
# 110   111                   The Polar Express2020 Re-release     -      -
# 112   113                   The Addams Family2020 Re-release     -      -
# 115   116                        Ghostbusters2020 Re-release     -      -
# 122   123             Guardians of the Galaxy2020 Re-release     -      -
# 132   133                          The Grinch2020 Re-release     -      -
# 138   139                Beauty and the Beast2020 Re-release     -      -
# 139   140                          Inside Out2020 Re-release     -      -
# 142   143                            Iron Man2020 Re-release     -      -
# 148   149                       Black Panther2020 Re-release     -      -
# 156   157                            Die Hard2020 Re-release     -      -
# 164   165                            Gremlins2020 Re-release     -      -
# 165   166      How the Grinch Stole Christmas2020 Re-release     -      -
# 169   170                An American in Paris2020 Re-release     -      -
# 170   171                        Wonder Woman2020 Re-release     -      -
# 171   172                  Back to the Future2020 Re-release     -      -
# 172   173                   Bohemian Rhapsody2020 Re-release     -      -
# 173   174                                              63 Up     -      -
# 174   175                    Tokyo Godfathers2020 Re-release     -      -
# 177   178                  Doctor Who Live Q&A And Screening     -      -
# 179   180                              Frozen2020 Re-release     -      -
# 182   183                                         Jiang Ziya     -      -
# 185   186  National Theater Live: Cyrano de Bergerac2020 ...     -      -
# 199   200                         Love Story50th Anniversary     -      -
#
#     Running Time        Gross Theaters  Total Gross Release Date  \
# 150            -   $7,192,291     1543   $7,192,291       Sep 25
# 170            -   $4,449,681      151  $52,522,904       Mar 19
# 198            -   $2,412,593      280   $2,412,593       Jan 30
# 153            -   $8,700,374      560   $8,700,374       May 13
# 173            -   $4,367,218      464   $4,267,218       Apr 22
# 180            -   $3,903,095      236   $3,903,095       Jul 21
# 100            -  $21,858,070     2705  $21,858,070       Aug 25
# 185            -   $3,100,479      901   $3,100,479        Sep 1
# 189            -   $2,835,355      272   $2,835,355       Feb 10
# 195            -   $2,620,183      532   $2,620,183       Aug 26
# 166            -   $6,016,007     1566   $6,100,309       Dec 12
# 168            -   $5,757,906       35   $7,574,012        Apr 6
# 196            -   $3,236,321       13   $3,236,321       May 18
# 51             -  $54,733,739     3372  $54,733,739       Apr 19
# 164            -   $4,427,217      270   $4,580,048       Dec 21
# 165            -   $4,403,322       89   $4,697,364       Jul 12
# 176            -   $3,531,094      415   $3,531,094        Feb 8
# 194            -   $2,410,795      268   $2,410,795        Feb 1
# 52             -   $4,828,000     2570   $4,828,000        Oct 2
# 60             -   $3,306,611      536   $3,306,611       Jan 31
# 66             -   $2,482,000     2097   $2,482,000       Jul 10
# 68             -   $2,286,000     2194   $2,286,000       Oct 16
# 71             -   $1,975,000      850   $2,003,568       Nov 13
# 78             -   $1,386,600      316   $1,386,600       Jun 19
# 92             -     $871,000      620     $871,000       Nov 25
# 96             -     $825,000      457     $825,000       Jul 10
# 100            -     $758,300      187     $758,300       Jun 19
# 104            -     $727,000     2102     $727,000        Nov 6
# 105            -     $726,000     1875     $726,000       Oct 23
# 107            -     $706,000     1581     $706,000       Nov 20
# 110            -     $691,000      450     $711,000        Dec 4
# 112            -     $678,926     1307     $678,926       Oct 23
# 115            -     $605,000      622     $605,000        Jul 3
# 122            -     $542,000     1560     $542,000       Nov 13
# 132            -     $502,781      450     $473,781       Nov 27
# 138            -     $467,000      527     $467,000       Jul 17
# 139            -     $460,000      442     $460,000       Jul 10
# 142            -     $430,000      462     $430,000       Jul 17
# 148            -     $367,000      421     $367,000       Jul 10
# 156            -     $325,000     1172     $325,000        Dec 4
# 164            -     $295,000       64     $295,000       Jul 10
# 165            -     $294,000      300     $420,180        Dec 4
# 169            -     $267,824      651     $267,824       Jan 19
# 170            -     $252,000      560     $252,000       Dec 11
# 171            -     $247,000      258     $247,000       Jul 31
# 172            -     $240,000        -     $240,000       Jul 17
# 173            -     $238,204       28     $483,684       Nov 27
# 174            -     $237,581      519     $237,571        Mar 9
# 177            -     $228,615      692     $228,615        Jan 5
# 179            -     $215,000     1367     $215,000       Nov 25
# 182            -     $206,975       55     $214,670        Oct 1
# 185            -     $198,352      472     $198,352       Feb 20
# 199            -     $153,504      650     $153,504        Feb 9
#
#                              Distributor  Estimated  Year
# 150                              BH Tilt      False  2015
# 170                         Warner Bros.      False  2015
# 198                 Shorts International      False  2015
# 153                                  A24      False  2016
# 173               Sony Pictures Classics      False  2016
# 180                                    -      False  2016
# 100                The Weinstein Company      False  2017
# 185    Sony Pictures Entertainment (SPE)      False  2017
# 189                 Shorts International      False  2017
# 195                        Fathom Events      False  2017
# 166                Twentieth Century Fox      False  2018
# 168                         Warner Bros.      False  2018
# 196                         Warner Bros.      False  2018
# 51                          Warner Bros.      False  2019
# 164                       Amazon Studios      False  2019
# 165                    Entertainment One      False  2019
# 176                 Shorts International      False  2019
# 194                Bleecker Street Media      False  2019
# 52   Walt Disney Studios Motion Pictures      False  2020
# 60                     Magnolia Pictures      False  2020
# 66   Walt Disney Studios Motion Pictures      False  2020
# 68   Walt Disney Studios Motion Pictures      False  2020
# 71                       New Line Cinema      False  2020
# 78                    Universal Pictures      False  2020
# 92                          Warner Bros.      False  2020
# 96                          Warner Bros.      False  2020
# 100                   Universal Pictures      False  2020
# 104  Walt Disney Studios Motion Pictures      False  2020
# 105  Walt Disney Studios Motion Pictures      False  2020
# 107  Walt Disney Studios Motion Pictures      False  2020
# 110                         Warner Bros.      False  2020
# 112             United Artists Releasing      False  2020
# 115                    Columbia Pictures      False  2020
# 122  Walt Disney Studios Motion Pictures      False  2020
# 132                   Universal Pictures      False  2020
# 138                 Walt Disney Pictures      False  2020
# 139                 Walt Disney Pictures      False  2020
# 142                 Walt Disney Pictures      False  2020
# 148                 Walt Disney Pictures      False  2020
# 156  Walt Disney Studios Motion Pictures      False  2020
# 164                                    -      False  2020
# 165                   Universal Pictures      False  2020
# 169                        Fathom Events      False  2020
# 170                         Warner Bros.      False  2020
# 171                   Universal Pictures      False  2020
# 172                Twentieth Century Fox      False  2020
# 173                              BritBox      False  2020
# 174                        Fathom Events      False  2020
# 177                        Fathom Events      False  2020
# 179  Walt Disney Studios Motion Pictures      False  2020
# 182            Well Go USA Entertainment      False  2020
# 185                        Fathom Events      False  2020
# 199                        Fathom Events      False  2020

# %%
# Merge boxoffice data with IMDb
moviedata = pd.merge(moviedata, boxoffice, how="outer", left_on="primaryTitle", right_on="Release")
# Remove duplicates by only keeping the first for now
moviedata = moviedata.groupby("Release").agg(lambda x: x.iloc[0])

print(moviedata.shape)
moviedata.head()
# Out:
# (1090, 28)
#                         tconst titleType         primaryTitle  \
# Release
# 10 Cloverfield Lane  tt1179933     movie  10 Cloverfield Lane
# 100% Wolf            tt8774798     movie            100% Wolf
# 12 Strong            tt1413492     movie            12 Strong
# 13 Hours             tt4172430     movie             13 Hours
# 1917                 tt8579674     movie                 1917
#
#                            originalTitle  isAdult  startYear  endYear  \
# Release
# 10 Cloverfield Lane  10 Cloverfield Lane      0.0     2016.0      NaN
# 100% Wolf                      100% Wolf      0.0     2020.0      NaN
# 12 Strong                      12 Strong      0.0     2018.0      NaN
# 13 Hours                        13 Hours      0.0     2016.0      NaN
# 1917                                1917      0.0     2019.0      NaN
#
#                      runtimeMinutes                      genres    titleId  \
# Release
# 10 Cloverfield Lane           103.0         Action,Drama,Horror  tt1179933
# 100% Wolf                      96.0  Adventure,Animation,Comedy  tt8774798
# 12 Strong                     130.0        Action,Drama,History  tt1413492
# 13 Hours                      144.0        Action,Drama,History  tt4172430
# 1917                          119.0            Action,Drama,War  tt8579674
#
#                      ...  Genre Budget Running Time         Gross Theaters  \
# Release              ...
# 10 Cloverfield Lane  ...      -      -            -   $72,082,998     3427
# 100% Wolf            ...      -      -            -      $514,957      124
# 12 Strong            ...      -      -            -   $45,819,713     3018
# 13 Hours             ...      -      -            -   $52,853,219     2917
# 1917                 ...      -      -            -  $157,901,466     3987
#
#                       Total Gross  Release Date         Distributor Estimated  \
# Release
# 10 Cloverfield Lane   $72,082,998        Mar 11  Paramount Pictures     False
# 100% Wolf                $658,764         Oct 9       Viva Pictures     False
# 12 Strong             $45,819,713        Jan 19        Warner Bros.     False
# 13 Hours              $52,853,219        Jan 15  Paramount Pictures     False
# 1917                 $159,227,644        Dec 25  Universal Pictures     False
#
#                        Year
# Release
# 10 Cloverfield Lane  2016.0
# 100% Wolf            2020.0
# 12 Strong            2018.0
# 13 Hours             2016.0
# 1917                 2020.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Back to IMDb to names associated with the movie (director and main actors names)

# %% [markdown]
# ### Get the list of people linked to the movie

# %%
################################################################
#  NOT USED SINCE `title.principals.tsv.gz` ACTUALLY CONTAINS  #
# THE MAIN PEOPLE THAT WORKED ON THE MOVIE, INCLUDING THE CREW #
################################################################

# Read the `title.crew.tsv.gz` table, which contains information about the movie's crew
# movie, director(s), writers
#crew = read_csv('title.crew.tsv.gz')

#print(crew.shape)
#crew.head()

# %%
# Read the `title.principals.tsv.gz` table, which contains information about the main people
# that worked on the movie (director, actor, etc)
principals = read_csv('title.principals.tsv.gz')

print(principals.shape)
principals.head()
# Out:
# (47576376, 6)
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                      NaN
# 1  tt0000001         2  nm0005690         director                      NaN
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt0000002         1  nm0721526         director                      NaN
# 4  tt0000002         2  nm1335271         composer                      NaN
#
#   characters
# 0   ["Self"]
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
# Merge the people that worked on the movie in the full movie dataset

# NOT USED, SEE ABOVE
# Crew of the movie
#moviedata = pd.merge(moviedata, crew, how="left", left_on="tconst", right_on="tconst")

# Main actors and crew of the movie
moviedata = pd.merge(moviedata, principals, how="left", left_on="tconst", right_on="tconst")

print(moviedata.shape)
moviedata.head()
# Out:
# (10207, 33)
#       tconst titleType         primaryTitle        originalTitle  isAdult  \
# 0  tt1179933     movie  10 Cloverfield Lane  10 Cloverfield Lane      0.0
# 1  tt1179933     movie  10 Cloverfield Lane  10 Cloverfield Lane      0.0
# 2  tt1179933     movie  10 Cloverfield Lane  10 Cloverfield Lane      0.0
# 3  tt1179933     movie  10 Cloverfield Lane  10 Cloverfield Lane      0.0
# 4  tt1179933     movie  10 Cloverfield Lane  10 Cloverfield Lane      0.0
#
#    startYear  endYear  runtimeMinutes               genres    titleId  ...  \
# 0     2016.0      NaN           103.0  Action,Drama,Horror  tt1179933  ...
# 1     2016.0      NaN           103.0  Action,Drama,Horror  tt1179933  ...
# 2     2016.0      NaN           103.0  Action,Drama,Horror  tt1179933  ...
# 3     2016.0      NaN           103.0  Action,Drama,Horror  tt1179933  ...
# 4     2016.0      NaN           103.0  Action,Drama,Horror  tt1179933  ...
#
#    Total Gross Release Date         Distributor Estimated    Year ordering_y  \
# 0  $72,082,998       Mar 11  Paramount Pictures     False  2016.0       10.0
# 1  $72,082,998       Mar 11  Paramount Pictures     False  2016.0        1.0
# 2  $72,082,998       Mar 11  Paramount Pictures     False  2016.0        2.0
# 3  $72,082,998       Mar 11  Paramount Pictures     False  2016.0        3.0
# 4  $72,082,998       Mar 11  Paramount Pictures     False  2016.0        4.0
#
#       nconst  category       job    characters
# 0  nm6618222  producer  producer           NaN
# 1  nm0000422     actor       NaN    ["Howard"]
# 2  nm0935541   actress       NaN  ["Michelle"]
# 3  nm0302330     actor       NaN    ["Emmett"]
# 4  nm0341174     actor       NaN    ["Driver"]
#
# [5 rows x 33 columns]

# %%
##############################################################
# UNUSED BECAUSE WE JUST WANT TO EXPORT THE DIRECTOR LIST AS #
#  IS, BUT CAN BE USEFUL FOR A QUICK ANALYSIS IN THIS FILE   #
##############################################################

# Split the director list into an array
#moviedata["directors"] = moviedata["directors"].apply(lambda x:x.split(","))

# Explode directors
#moviedata = moviedata.explode('directors')

#print(moviedata.shape)
#moviedata.head()

# %% [markdown]
# ### Retrieve names from the ids

# %%
# Read the `name.basic.tsv.gz` table, which maps an unique identifier to a name
# identifier, name, profession, birth, death, known for...
names = read_csv('name.basics.tsv.gz')

# %%
# Merge the names with the rest of the data
moviedata = pd.merge(moviedata, names, how="inner", left_on="nconst", right_on="nconst")

print(moviedata.shape)
moviedata.head()
# Out:
# (10149, 38)
#       tconst titleType         primaryTitle        originalTitle  isAdult  \
# 0  tt1179933     movie  10 Cloverfield Lane  10 Cloverfield Lane      0.0
# 1  tt4530422     movie             Overlord             Overlord      0.0
# 2  tt1179933     movie  10 Cloverfield Lane  10 Cloverfield Lane      0.0
# 3  tt2406566     movie        Atomic Blonde        Atomic Blonde      0.0
# 4  tt5968394     movie        Captive State        Captive State      0.0
#
#    startYear  endYear  runtimeMinutes                genres    titleId  ...  \
# 0     2016.0      NaN           103.0   Action,Drama,Horror  tt1179933  ...
# 1     2018.0      NaN           110.0  Action,Horror,Sci-Fi  tt4530422  ...
# 2     2016.0      NaN           103.0   Action,Drama,Horror  tt1179933  ...
# 3     2017.0      NaN           115.0       Action,Thriller  tt2406566  ...
# 4     2019.0      NaN           109.0  Action,Horror,Sci-Fi  tt5968394  ...
#
#    ordering_y     nconst  category       job            characters  \
# 0        10.0  nm6618222  producer  producer                   NaN
# 1         9.0  nm6618222  producer  producer                   NaN
# 2         1.0  nm0000422     actor       NaN            ["Howard"]
# 3         3.0  nm0000422     actor       NaN   ["Emmett Kurzfeld"]
# 4         1.0  nm0000422     actor       NaN  ["William Mulligan"]
#
#      primaryName  birthYear  deathYear          primaryProfession  \
# 0  Lindsey Weber        NaN        NaN                   producer
# 1  Lindsey Weber        NaN        NaN                   producer
# 2   John Goodman     1952.0        NaN  actor,soundtrack,producer
# 3   John Goodman     1952.0        NaN  actor,soundtrack,producer
# 4   John Goodman     1952.0        NaN  actor,soundtrack,producer
#
#                             knownForTitles
# 0  tt4530422,tt2660888,tt2548396,tt1179933
# 1  tt4530422,tt2660888,tt2548396,tt1179933
# 2  tt0101410,tt1179933,tt1024648,tt1907668
# 3  tt0101410,tt1179933,tt1024648,tt1907668
# 4  tt0101410,tt1179933,tt1024648,tt1907668
#
# [5 rows x 38 columns]

# %%
# Export the final merged data into an unique file
moviedata.to_csv(OUT_DATASET)
